# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv(r'C:\Users\User\Desktop\data_hub\tracks.csv')

# %%
data.head(5)
# Out:
#                        id                                 name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                Carve           6
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista           0
# 2  07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado           0
# 3  08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado           0
# 4  08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening           0
#
#    duration_ms  explicit              artists                  id_artists  \
# 0       126903         0              ['Uli']  ['45tIt06XoI0Iio4LBEVpls']
# 1        98200         0  ['Fernando Pessoa']  ['14jtPCOoNZwquk5wd9DxrY']
# 2       181640         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 3       176907         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 4       163080         0      ['Dick Haymes']  ['3BiJGZsyX9sJchTqcSA7Su']
#
# ...

# %%
data.shape
# Out:
# (586672, 20)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 586672 entries, 0 to 586671
# Data columns (total 20 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                586672 non-null  object
#  1   name              586601 non-null  object
#  2   popularity        586672 non-null  int64
#  3   duration_ms       586672 non-null  int64
#  4   explicit          586672 non-null  int64
#  5   artists           586672 non-null  object
#  6   id_artists        586672 non-null  object
#  7   release_date      586672 non-null  object
#  8   danceability      586672 non-null  float64
#  9   energy            586672 non-null  float64
#  10  key               586672 non-null  int64
#  11  loudness          586672 non-null  float64
#  12  mode              586672 non-null  int64
#  13  speechiness       586672 non-null  float64
#  14  acousticness      586672 non-null  float64
#  15  instrumentalness  586672 non-null  float64
# ...

# %%
data.isnull().sum()
# Out:
# id                   0
# name                71
# popularity           0
# duration_ms          0
# explicit             0
# artists              0
# id_artists           0
# release_date         0
# danceability         0
# energy               0
# key                  0
# loudness             0
# mode                 0
# speechiness          0
# acousticness         0
# instrumentalness     0
# liveness             0
# valence              0
# tempo                0
# time_signature       0
# dtype: int64

# %%
data.columns
# Out:
# Index(['id', 'name', 'popularity', 'duration_ms', 'explicit', 'artists',
#        'id_artists', 'release_date', 'danceability', 'energy', 'key',
#        'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
#        'liveness', 'valence', 'tempo', 'time_signature'],
#       dtype='object')

# %%
data.sort_values(by='popularity',ascending=False).head(5)
# Out:
#                            id                                    name  \
# 93802  4iJyoBOLtHqaGxP12qzhQI  Peaches (feat. Daniel Caesar & Giveon)
# 93803  7lPN2DXiMsVn7XUKtOW1CS                         drivers license
# 93804  3Ofmpyhv5UAQ70mENzB277                  Astronaut In The Ocean
# 92810  5QO79kh1waicV47BqGRL3g                         Save Your Tears
# 92811  6tDDoYIxWvMLTdKpjFkc1B                               telepatía
#
#        popularity  duration_ms  explicit  \
# 93802         100       198082         1
# 93803          99       242014         1
# 93804          98       132780         0
# 92810          97       215627         1
# 92811          97       160191         0
#
#                                             artists  \
# 93802  ['Justin Bieber', 'Daniel Caesar', 'Giveon']
# 93803                            ['Olivia Rodrigo']
# 93804                               ['Masked Wolf']
# 92810                                ['The Weeknd']
# ...

# %%
data.describe().transpose()
# Out:
#                      count           mean            std     min          25%  \
# popularity        586672.0      27.570053      18.370642     0.0      13.0000
# duration_ms       586672.0  230051.167286  126526.087418  3344.0  175093.0000
# explicit          586672.0       0.044086       0.205286     0.0       0.0000
# danceability      586672.0       0.563594       0.166103     0.0       0.4530
# energy            586672.0       0.542036       0.251923     0.0       0.3430
# key               586672.0       5.221603       3.519423     0.0       2.0000
# loudness          586672.0     -10.206067       5.089328   -60.0     -12.8910
# mode              586672.0       0.658797       0.474114     0.0       0.0000
# speechiness       586672.0       0.104864       0.179893     0.0       0.0340
# acousticness      586672.0       0.449863       0.348837     0.0       0.0969
# instrumentalness  586672.0       0.113451       0.266868     0.0       0.0000
# ...

# %%
data[data['popularity']>90].shape
# Out:
# (37, 20)

# %%
data[data['popularity']>90].sort_values(by='popularity',ascending=False).head(5)
# Out:
#                            id                                    name  \
# 93802  4iJyoBOLtHqaGxP12qzhQI  Peaches (feat. Daniel Caesar & Giveon)
# 93803  7lPN2DXiMsVn7XUKtOW1CS                         drivers license
# 93804  3Ofmpyhv5UAQ70mENzB277                  Astronaut In The Ocean
# 92810  5QO79kh1waicV47BqGRL3g                         Save Your Tears
# 92811  6tDDoYIxWvMLTdKpjFkc1B                               telepatía
#
#        popularity  duration_ms  explicit  \
# 93802         100       198082         1
# 93803          99       242014         1
# 93804          98       132780         0
# 92810          97       215627         1
# 92811          97       160191         0
#
#                                             artists  \
# 93802  ['Justin Bieber', 'Daniel Caesar', 'Giveon']
# 93803                            ['Olivia Rodrigo']
# 93804                               ['Masked Wolf']
# 92810                                ['The Weeknd']
# ...

# %%
most_popular=data[data['popularity']>90].sort_values(by='popularity',ascending=False)

# %%
most_popular.head(5)
# Out:
#                            id                                    name  \
# 93802  4iJyoBOLtHqaGxP12qzhQI  Peaches (feat. Daniel Caesar & Giveon)
# 93803  7lPN2DXiMsVn7XUKtOW1CS                         drivers license
# 93804  3Ofmpyhv5UAQ70mENzB277                  Astronaut In The Ocean
# 92810  5QO79kh1waicV47BqGRL3g                         Save Your Tears
# 92811  6tDDoYIxWvMLTdKpjFkc1B                               telepatía
#
#        popularity  duration_ms  explicit  \
# 93802         100       198082         1
# 93803          99       242014         1
# 93804          98       132780         0
# 92810          97       215627         1
# 92811          97       160191         0
#
#                                             artists  \
# 93802  ['Justin Bieber', 'Daniel Caesar', 'Giveon']
# 93803                            ['Olivia Rodrigo']
# 93804                               ['Masked Wolf']
# 92810                                ['The Weeknd']
# ...

# %%
data['release_date'].value_counts()
# Out:
# release_date
# 1998-01-01    2893
# 1997-01-01    2892
# 1995          2871
# 1997          2811
# 1996          2776
#               ...
# 1954-03-17       1
# 2012-01-29       1
# 1959-02-14       1
# 1968-05          1
# 2009-11-28       1
# Name: count, Length: 19700, dtype: int64

# %%
data['duration']=data['duration_ms'].apply(lambda x: round (x/1000))

# %%
data.drop(columns=['duration_ms'],inplace=True,axis=1)

# %%
data.head(5)
# Out:
#                        id                                 name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                Carve           6
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista           0
# 2  07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado           0
# 3  08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado           0
# 4  08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening           0
#
#    explicit              artists                  id_artists release_date  \
# 0         0              ['Uli']  ['45tIt06XoI0Iio4LBEVpls']   1922-02-22
# 1         0  ['Fernando Pessoa']  ['14jtPCOoNZwquk5wd9DxrY']   1922-06-01
# 2         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']   1922-03-21
# 3         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']   1922-03-21
# 4         0      ['Dick Haymes']  ['3BiJGZsyX9sJchTqcSA7Su']         1922
#
# ...

# %%
data.columns
# Out:
# Index(['id', 'name', 'popularity', 'explicit', 'artists', 'id_artists',
#        'release_date', 'danceability', 'energy', 'key', 'loudness', 'mode',
#        'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'time_signature', 'duration'],
#       dtype='object')

# %%
data.head(5)
# Out:
#                        id                                 name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                Carve           6
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista           0
# 2  07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado           0
# 3  08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado           0
# 4  08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening           0
#
#    explicit              artists                  id_artists release_date  \
# 0         0              ['Uli']  ['45tIt06XoI0Iio4LBEVpls']   1922-02-22
# 1         0  ['Fernando Pessoa']  ['14jtPCOoNZwquk5wd9DxrY']   1922-06-01
# 2         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']   1922-03-21
# 3         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']   1922-03-21
# 4         0      ['Dick Haymes']  ['3BiJGZsyX9sJchTqcSA7Su']         1922
#
# ...

# %%
data1=data[['id', 'name','artists','artists', 'id_artists','release_date']]

# %%
data2=data[['popularity', 'explicit', 'danceability', 'energy', 'key', 'loudness', 'mode','speechiness', 'acousticness', 'instrumentalness', 'liveness','valence', 'tempo', 'time_signature', 'duration']]

# %%
#sns.heatmap(data2.corr())
correlation = data2.corr(method='pearson')

# %%
correlation
# Out:
#                   popularity  explicit  danceability    energy       key  \
# popularity          1.000000  0.211758      0.187000  0.302315  0.015299
# explicit            0.211758  1.000000      0.150229  0.123076  0.010932
# danceability        0.187000  0.150229      1.000000  0.241563  0.018824
# energy              0.302315  0.123076      0.241563  1.000000  0.036294
# key                 0.015299  0.010932      0.018824  0.036294  1.000000
# loudness            0.327028  0.134603      0.251436  0.764735  0.027109
# mode               -0.033655 -0.051754     -0.044719 -0.065246 -0.129491
# speechiness        -0.047357  0.102258      0.199310 -0.053506 -0.001035
# acousticness       -0.370882 -0.149018     -0.242951 -0.715412 -0.027414
# instrumentalness   -0.236487 -0.067520     -0.225900 -0.195839 -0.006776
# liveness           -0.048740 -0.013114     -0.106168  0.124632 -0.006774
# valence             0.004643 -0.016539      0.528150  0.372276  0.019992
# ...

# %%
data.columns
# Out:
# Index(['id', 'name', 'popularity', 'explicit', 'artists', 'id_artists',
#        'release_date', 'danceability', 'energy', 'key', 'loudness', 'mode',
#        'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'time_signature', 'duration'],
#       dtype='object')

# %%
data3=data[['key','mode','explicit']].corr(method='pearson')

# %%
data3
# Out:
#                key      mode  explicit
# key       1.000000 -0.129491  0.010932
# mode     -0.129491  1.000000 -0.051754
# explicit  0.010932 -0.051754  1.000000

# %%
sns.heatmap(data3,annot=True,fmt='.1g',vmin=-1,vmax=1,center=0,cmap='inferno')
plt.title('correlation heatmap beween variables')
plt.show()

# %%
sample_data=data.sample(int(.004*len(data)))

# %%
len(sample_data)
# Out:
# 2346

# %%
plt.figure(figsize=(8,4))
sns.regplot(data=sample_data,x='energy',y='loudness',color='c').set_title('Loudness vs soundness correlation')
plt.show()

# %%
plt.figure(figsize=(8,4))
sns.regplot(data=sample_data,x='acousticness',y='loudness',color='c').set_title('Loudness vs acousticness correlation')
plt.show()

# %%
from datetime import datetime
year = datetime.today().year

# %%
data=pd.read_csv(r'C:\Users\User\Desktop\data_hub\SpotifyFeatures.csv')

# %%
data.head(3)
# Out:
#    genre        artist_name                        track_name  \
# 0  Movie     Henri Salvador       C'est beau de faire un Show
# 1  Movie  Martin & les fées  Perdu d'avance (par Gad Elmaleh)
# 2  Movie    Joseph Williams    Don't Let Me Be Lonely Tonight
#
#                  track_id  popularity  acousticness  danceability  \
# 0  0BRjO6ga9RKCKjfDqeFgWV           0         0.611         0.389
# 1  0BjC1NfoEOOusryehmNudP           1         0.246         0.590
# 2  0CoSDzoNIKCRs124s9uTVy           3         0.952         0.663
#
#    duration_ms  energy  instrumentalness key  liveness  loudness   mode  \
# 0        99373   0.910               0.0  C#     0.346    -1.828  Major
# 1       137373   0.737               0.0  F#     0.151    -5.559  Minor
# 2       170267   0.131               0.0   C     0.103   -13.879  Minor
#
#    speechiness    tempo time_signature  valence
# 0       0.0525  166.969            4/4    0.814
# 1       0.0868  174.003            4/4    0.816
# ...

# %%
data['duration_ms']=data['duration_ms'].apply(lambda x: round(x/1000))

# %%
data.head(3)
# Out:
#    genre        artist_name                        track_name  \
# 0  Movie     Henri Salvador       C'est beau de faire un Show
# 1  Movie  Martin & les fées  Perdu d'avance (par Gad Elmaleh)
# 2  Movie    Joseph Williams    Don't Let Me Be Lonely Tonight
#
#                  track_id  popularity  acousticness  danceability  \
# 0  0BRjO6ga9RKCKjfDqeFgWV           0         0.611         0.389
# 1  0BjC1NfoEOOusryehmNudP           1         0.246         0.590
# 2  0CoSDzoNIKCRs124s9uTVy           3         0.952         0.663
#
#    duration_ms  energy  instrumentalness key  liveness  loudness   mode  \
# 0           99   0.910               0.0  C#     0.346    -1.828  Major
# 1          137   0.737               0.0  F#     0.151    -5.559  Minor
# 2          170   0.131               0.0   C     0.103   -13.879  Minor
#
#    speechiness    tempo time_signature  valence
# 0       0.0525  166.969            4/4    0.814
# 1       0.0868  174.003            4/4    0.816
# ...

# %%
len(data['genre'].value_counts().sort_values(ascending=False))
# Out:
# 27

# %%
plt.figure(figsize=(30,6))
sns.barplot(data=data,x='genre',y='duration_ms')
# Out:
# <Axes: xlabel='genre', ylabel='duration_ms'>

# %%
data.groupby('genre')['duration_ms'].sum().sort_values(ascending=False).head(10).plot(kind='barh')
plt.show()

# %%
data.columns
# Out:
# Index(['genre', 'artist_name', 'track_name', 'track_id', 'popularity',
#        'acousticness', 'danceability', 'duration_ms', 'energy',
#        'instrumentalness', 'key', 'liveness', 'loudness', 'mode',
#        'speechiness', 'tempo', 'time_signature', 'valence'],
#       dtype='object')

# %%
data.head(3)
# Out:
#    genre        artist_name                        track_name  \
# 0  Movie     Henri Salvador       C'est beau de faire un Show
# 1  Movie  Martin & les fées  Perdu d'avance (par Gad Elmaleh)
# 2  Movie    Joseph Williams    Don't Let Me Be Lonely Tonight
#
#                  track_id  popularity  acousticness  danceability  \
# 0  0BRjO6ga9RKCKjfDqeFgWV           0         0.611         0.389
# 1  0BjC1NfoEOOusryehmNudP           1         0.246         0.590
# 2  0CoSDzoNIKCRs124s9uTVy           3         0.952         0.663
#
#    duration_ms  energy  instrumentalness key  liveness  loudness   mode  \
# 0           99   0.910               0.0  C#     0.346    -1.828  Major
# 1          137   0.737               0.0  F#     0.151    -5.559  Minor
# 2          170   0.131               0.0   C     0.103   -13.879  Minor
#
#    speechiness    tempo time_signature  valence
# 0       0.0525  166.969            4/4    0.814
# 1       0.0868  174.003            4/4    0.816
# ...

# %%
data['artist_name'].nunique()
# Out:
# 14564

# %%
data.shape
# Out:
# (232725, 18)

# %%
popular_actor=data.groupby('artist_name')['popularity'].sum().sort_values(ascending=False).head(10).reset_index()

# %%
plt.figure(figsize=(20,6))
sns.barplot(data=popular_actor,x='artist_name',y='popularity')
plt.xticks(rotation=70)
plt.show()

# %%
len(data[data['artist_name']=='Drake'])
# Out:
# 477

# %%
data.head(3)
# Out:
#    genre        artist_name                        track_name  \
# 0  Movie     Henri Salvador       C'est beau de faire un Show
# 1  Movie  Martin & les fées  Perdu d'avance (par Gad Elmaleh)
# 2  Movie    Joseph Williams    Don't Let Me Be Lonely Tonight
#
#                  track_id  popularity  acousticness  danceability  \
# 0  0BRjO6ga9RKCKjfDqeFgWV           0         0.611         0.389
# 1  0BjC1NfoEOOusryehmNudP           1         0.246         0.590
# 2  0CoSDzoNIKCRs124s9uTVy           3         0.952         0.663
#
#    duration_ms  energy  instrumentalness key  liveness  loudness   mode  \
# 0           99   0.910               0.0  C#     0.346    -1.828  Major
# 1          137   0.737               0.0  F#     0.151    -5.559  Minor
# 2          170   0.131               0.0   C     0.103   -13.879  Minor
#
#    speechiness    tempo time_signature  valence
# 0       0.0525  166.969            4/4    0.814
# 1       0.0868  174.003            4/4    0.816
# ...

# %%
data.nunique()
# Out:
# genre                   27
# artist_name          14564
# track_name          148614
# track_id            176774
# popularity             101
# acousticness          4734
# danceability          1295
# duration_ms           1310
# energy                2517
# instrumentalness      5400
# key                     12
# liveness              1732
# loudness             27923
# mode                     2
# speechiness           1641
# tempo                78512
# time_signature           5
# valence               1692
# dtype: int64

# %%
data['time_signature'].unique()
# Out:
# array(['4/4', '5/4', '3/4', '1/4', '0/4'], dtype=object)

# %%
data.groupby('time_signature')['popularity'].sum().sort_values(ascending=False)
# Out:
# time_signature
# 4/4    8557927
# 3/4     768130
# 5/4     170994
# 1/4      74045
# 0/4        302
# Name: popularity, dtype: int64

# %%
data.groupby('time_signature')['popularity'].sum().sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='time_signature'>

# %%
data.head(3)
# Out:
#    genre        artist_name                        track_name  \
# 0  Movie     Henri Salvador       C'est beau de faire un Show
# 1  Movie  Martin & les fées  Perdu d'avance (par Gad Elmaleh)
# 2  Movie    Joseph Williams    Don't Let Me Be Lonely Tonight
#
#                  track_id  popularity  acousticness  danceability  \
# 0  0BRjO6ga9RKCKjfDqeFgWV           0         0.611         0.389
# 1  0BjC1NfoEOOusryehmNudP           1         0.246         0.590
# 2  0CoSDzoNIKCRs124s9uTVy           3         0.952         0.663
#
#    duration_ms  energy  instrumentalness key  liveness  loudness   mode  \
# 0           99   0.910               0.0  C#     0.346    -1.828  Major
# 1          137   0.737               0.0  F#     0.151    -5.559  Minor
# 2          170   0.131               0.0   C     0.103   -13.879  Minor
#
#    speechiness    tempo time_signature  valence
# 0       0.0525  166.969            4/4    0.814
# 1       0.0868  174.003            4/4    0.816
# ...

# %%
data.groupby('genre')['popularity'].sum().sort_values(ascending=False).head(5)
# Out:
# genre
# Pop        625020
# Rap        558848
# Rock       552791
# Hip-Hop    543043
# Indie      522017
# Name: popularity, dtype: int64

# %%
data.groupby('genre')['popularity'].sum().sort_values(ascending=False).head(10).plot(kind='barh')
plt.show()

# %%
data.columns
# Out:
# Index(['genre', 'artist_name', 'track_name', 'track_id', 'popularity',
#        'acousticness', 'danceability', 'duration_ms', 'energy',
#        'instrumentalness', 'key', 'liveness', 'loudness', 'mode',
#        'speechiness', 'tempo', 'time_signature', 'valence'],
#       dtype='object')

# %%
data.groupby('genre')['valence'].sum().sort_values(ascending=False).head(10).round(2)
# Out:
# genre
# Reggae       5961.35
# Reggaeton    5886.81
# Ska          5798.91
# Blues        5228.15
# Jazz         4805.10
# Rock         4794.67
# Country      4636.62
# Pop          4518.15
# Dance        4504.98
# Hip-Hop      4400.07
# Name: valence, dtype: float64

# %%
plt.figure(figsize=(15,8))
data.groupby('genre')['loudness'].sum().sort_values().plot(kind='barh')
plt.show()

# %%
plt.figure(figsize=(12,6))
data.groupby('genre')['energy'].sum().sort_values(ascending=False).plot(kind='bar')
plt

# %%
data['genre'].value_counts().sort_values(ascending=False)
# Out:
# genre
# Comedy              9681
# Soundtrack          9646
# Indie               9543
# Jazz                9441
# Pop                 9386
# Electronic          9377
# Children’s Music    9353
# Folk                9299
# Hip-Hop             9295
# Rock                9272
# Alternative         9263
# Classical           9256
# Rap                 9232
# World               9096
# Soul                9089
# Blues               9023
# R&B                 8992
# Anime               8936
# Reggaeton           8927
# Ska                 8874
# Reggae              8771
# Dance               8701
# Country             8664
# Opera               8280
# Movie               7806
# Children's Music    5403
# A Capella            119
# Name: count, dtype: int64
